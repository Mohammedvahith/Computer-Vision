# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.7.1-cp39-cp39-win_amd64.whl (7.6 MB)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\vahith\lib\site-packages (from matplotlib) (22.0)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp39-cp39-win_amd64.whl (55 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp39-cp39-win_amd64.whl (160 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\vahith\lib\site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: numpy>=1.20 in c:\programdata\anaconda3\envs\vahith\lib\site-packages (from matplotlib) (1.24.1)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.4.0-cp39-cp39-win_amd64.whl (2.5 MB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.39.2-py3-none-any.whl (1.0 MB)
# Collecting zipp>=3.1.0
#   Using cached zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\vahith\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: zipp, pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, importlib-resources, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.2 importlib-resources-5.12.0 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.4.0 pyparsing-3.0.9 zipp-3.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as n
from matplotlib import pyplot as plt

# %%
img=cv2.imread("pic.jpg")
img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
grey=cv2.imread("pic.jpg",0)
cv2.imshow("grey",grey)
cv2.waitKey(0)
grey2=cv2.cvtColor(grey,cv2.COLOR_BGR2RGB)
plt.imshow(grey2)

# %%
img_1=cv2.medianBlur(grey,3)
adpt=cv2.adaptiveThreshold(grey,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,101,3)
plt.imshow(adpt)
